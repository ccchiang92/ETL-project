# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
article_df=pd.read_csv('../raw_data/article.csv')
article_df.head()
# Out:
#                 date                                            article
# 0  December 31, 2019  December 31, 2019 -Cases of pneumonia detected...
# 1    January 1, 2020  January 1, 2020 -Chinese health authorities cl...
# 2    January 5, 2020  January 5, 2020 -China announces that the unkn...
# 3    January 7, 2020  January 7, 2020 -Chinese authorities confirm t...
# 4   January 11, 2020  January 11, 2020 -The Wuhan Municipal Health C...

# %%
article_df['date'] =  pd.to_datetime(article_df['date'])

# %%
article_df
# Out:
#          date                                            article
# 0  2019-12-31  December 31, 2019 -Cases of pneumonia detected...
# 1  2020-01-01  January 1, 2020 -Chinese health authorities cl...
# 2  2020-01-05  January 5, 2020 -China announces that the unkn...
# 3  2020-01-07  January 7, 2020 -Chinese authorities confirm t...
# 4  2020-01-11  January 11, 2020 -The Wuhan Municipal Health C...
# 5  2020-01-13  January 13, 2020 -Thai authoritiesreport a cas...
# 6  2020-01-16  January 16, 2020 -Japanese authorities confirm...
# 7  2020-01-17  January 17, 2020 -Chinese health officials con...
# 8  2020-01-20  January 20, 2020 -The National Institutes of H...
# 9  2020-01-21  January 21, 2020 -Officials in Washington stat...
# 10 2020-01-22  January 22, 2020 -Wuhan says it will "temporar...
# 11 2020-01-23  January 23, 2020 -The Beijing Culture and Tour...
# 12 2020-01-26  January 26, 2020 -The China Association of Tra...
# ...

# %%
article_df.to_csv('../cleaned_data/article_new.csv',index=False)
